# %%
import pandas as pd

# %%
data = pd.read_csv('out_people_csv/tarajm_people.csv')
data.tail()
# Out:
#           id                              url  http_status  \
# 26766  83237  https://tarajm.com/people/83237          200
# 26767  91393  https://tarajm.com/people/91393          200
# 26768  59572  https://tarajm.com/people/59572          200
# 26769  63938  https://tarajm.com/people/63938          200
# 26770  92643  https://tarajm.com/people/92643          200
#
#              scraped_at_utc                                          name  \
# 26766  2026-02-11T22:14:50Z  قاسم بن أحمد بن نظام الدين العمري المانكبوري
# 26767  2026-02-11T22:14:52Z             أبي القاسم بن جمال الدين الكشميري
# 26768  2026-02-11T22:14:54Z                           جمال الدين الكشميري
# 26769  2026-02-11T22:14:56Z     أحمد بن نظام الدين بن فيض الله المانكبوري
# 26770  2026-02-11T22:14:58Z                   كمال الدين بن موسى الكشميري
#
#                                                  summary  \
# 26766  الشيخ قاسم بن أحمد المانكبوري الشيخ الصالح قاس...
# 26767  القاضي أبو القاسم الكشميري الشيخ العالم الصالح...
# 26768  مولانا جمال الدين الكشميري الشيخ العالم المحدث...
# 26769  الشيخ أحمد بن نظام المانكبوري الشيخ الصالح أحم...
# 26770  القاضي كمال بن موسى الكشميري الشيخ الفاضل العل...
#
#                                              translation  \
# 26766  الشيخ قاسم بن أحمد المانكبوري\nالشيخ الصالح قا...
# 26767  القاضي أبو القاسم الكشميري\nالشيخ العالم الصال...
# 26768  مولانا جمال الدين الكشميري\nالشيخ العالم المحد...
# 26769  الشيخ أحمد بن نظام المانكبوري\nالشيخ الصالح أح...
# 26770  القاضي كمال بن موسى الكشميري\nالشيخ الفاضل الع...
#
#                                              fields_json page_sections_json  \
# 26766  {"الحياة والتاريخ":{"الوفاة":{"type":"text","t...                 []
# 26767  {"الأماكن":{"مكان الميلاد":{"type":"links","it...                 []
# 26768  {"الأماكن":{"أماكن الإقامة":{"type":"links","i...                 []
# 26769  {"الحياة والتاريخ":{"الوفاة":{"type":"text","t...                 []
# 26770  {"الحياة والتاريخ":{"الوفاة":{"type":"text","t...                 []
#
#                                                all_hrefs
# 26766  https://tarajm.com/people/63938\nhttps://taraj...
# 26767  https://tarajm.com/people/92643\nhttps://taraj...
# 26768  https://tarajm.com/people/94053\nhttps://taraj...
# 26769  https://tarajm.com/people/83237\nhttps://taraj...
# 26770  https://tarajm.com/people/91393\nhttps://taraj...

# %%
data.shape
# Out:
# (26771, 10)

# %%
from pprint import pprint
print(data['name'][-1:].values)
pprint(data['summary'][-1:].values)
pprint(data['translation'][-1:].values)
# Out:
# ['كمال الدين بن موسى الكشميري']
# array(['القاضي كمال بن موسى الكشميري الشيخ الفاضل العلامة كمال الدين بن موسى الحنفي الكشميري، أحد فحول العلماء، انتقل من كشمير إلى سيالكوت سنة 971 هـ، فدرس وأفاد بها مدة عمره حتى ظهر تقدمه في فنون منها المنطق والحكمة والكلام وأصول الفقه'],
#       dtype=object)
# array(['القاضي كمال بن موسى الكشميري\nالشيخ الفاضل العلامة كمال الدين بن موسى الحنفي الكشميري، أحد فحول العلماء، انتقل من كشمير إلى سيالكوت سنة 971 هـ، فدرس وأفاد بها مدة عمره حتى ظهر تقدمه في فنون منها المنطق والحكمة والكلام وأصول الفقه، وكان مفرط الذكاء سريع الحفظ، مدرساً محسناً إلى طلبة العلم، كثير الإستغراق في مطالعة الكتب وتدريسها، أخذ عنه العلامة عبد الحكيم بن شمس الدين السيالكوتي والشيخ أحمد بن عبد الأحد العمري السرهندي وجمع كثير من العلماء. توفي سنة سبع عشرة وألف بلاهور فدفن بها، كما في روضة الأبرار.\nالإعلام بمن في تاريخ الهند من الأعلام المسمى بـ (نزهة الخواطر وبهجة المسامع والنواظر)'],
#       dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26771 entries, 0 to 26770
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  26771 non-null  int64
#  1   url                 26771 non-null  object
#  2   http_status         26771 non-null  int64
#  3   scraped_at_utc      26771 non-null  object
#  4   name                26768 non-null  object
#  5   summary             26624 non-null  object
#  6   translation         26526 non-null  object
#  7   fields_json         26771 non-null  object
#  8   page_sections_json  26771 non-null  object
#  9   all_hrefs           26768 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 2.0+ MB

# %%
data.to_parquet('out_people_csv/tarajm_people.parquet', index=False)
